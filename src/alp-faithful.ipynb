# %%
# !apt-get update && apt-get install -y git-lfs
# !git lfs install
# !pip install -q transformers datasets sacrebleu tqdm peft

# %%
# !git clone https://github.com/Mingowzm/anlp-fall2025-faithful.git
# %cd anlp-fall2025-faithful
# !git lfs pull
# !tar -xvjf data/wikilarge.tar.bz2 -C data/
# %cd src

# %%
# !python run_exp.py --train_type lora --model_name t5-small --use_proxy_loss --lambda1 0.3
